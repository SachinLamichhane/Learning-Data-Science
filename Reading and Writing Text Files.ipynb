# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %%
dframe = pd.read_csv('D:/project nitratescouts database/python/all_data.csv',header = None)
dframe.head()
# Out:
#           0                           1                 2           3  \
# 0  Order ID                     Product  Quantity Ordered  Price Each
# 1    176558        USB-C Charging Cable                 2       11.95
# 2       NaN                         NaN               NaN         NaN
# 3    176559  Bose SoundSport Headphones                 1       99.99
# 4    176560                Google Phone                 1         600
#
#                 4                                     5
# 0      Order Date                      Purchase Address
# 1  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 2             NaN                                   NaN
# 3  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001

# %%
pd.read_csv('D:/project nitratescouts database/python/all_data.csv',header = None, nrows= 2)
# Out:
#           0                     1                 2           3  \
# 0  Order ID               Product  Quantity Ordered  Price Each
# 1    176558  USB-C Charging Cable                 2       11.95
#
#                 4                             5
# 0      Order Date              Purchase Address
# 1  04/19/19 08:46  917 1st St, Dallas, TX 75001

# %%
dframe
# Out:
#                0                           1                 2           3  \
# 0       Order ID                     Product  Quantity Ordered  Price Each
# 1         176558        USB-C Charging Cable                 2       11.95
# 2            NaN                         NaN               NaN         NaN
# 3         176559  Bose SoundSport Headphones                 1       99.99
# 4         176560                Google Phone                 1         600
# ...          ...                         ...               ...         ...
# 186846    259353      AAA Batteries (4-pack)                 3        2.99
# 186847    259354                      iPhone                 1         700
# 186848    259355                      iPhone                 1         700
# 186849    259356      34in Ultrawide Monitor                 1      379.99
# 186850    259357        USB-C Charging Cable                 1       11.95
#
#                      4                                        5
# ...

# %%
dframe.to_csv('newdata.csv')

# %%
import sys

# %%
dframe.to_csv(sys.stdout, columns=[0,1,2])
# Out:
# ,0,1,2
# 0,Order ID,Product,Quantity Ordered
# 1,176558,USB-C Charging Cable,2
# 2,,,
# 3,176559,Bose SoundSport Headphones,1
# 4,176560,Google Phone,1
# 5,176560,Wired Headphones,1
# 6,176561,Wired Headphones,1
# 7,176562,USB-C Charging Cable,1
# 8,176563,Bose SoundSport Headphones,1
# 9,176564,USB-C Charging Cable,1
# 10,176565,Macbook Pro Laptop,1
# 11,176566,Wired Headphones,1
# 12,176567,Google Phone,1
# 13,176568,Lightning Charging Cable,1
# 14,176569,27in 4K Gaming Monitor,1
# 15,176570,AA Batteries (4-pack),1
# 16,176571,Lightning Charging Cable,1
# 17,176572,Apple Airpods Headphones,1
# 18,176573,USB-C Charging Cable,1
# 19,176574,Google Phone,1
# 20,176574,USB-C Charging Cable,1
# 21,176575,AAA Batteries (4-pack),1
# 22,176576,Apple Airpods Headphones,1
# 23,176577,Apple Airpods Headphones,1
# 24,176578,Apple Airpods Headphones,1
# 25,176579,AA Batteries (4-pack),1
# 26,176580,USB-C Charging Cable,1
# 27,176581,iPhone,1
# 28,176582,Bose SoundSport Headphones,1
# ...
